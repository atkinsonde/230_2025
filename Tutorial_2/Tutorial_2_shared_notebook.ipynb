# %% [markdown]
# # Tutorial 2 - Using Gemini (Generative AI)
# For using AI, the most difficult part is creating Prompts (asking questions).<br>
# You should be careful to:<br>
#
# 1. Ask clear and focused questions: <br>
# When asking questions to AI, provide specific and detailed information. By clearly explaining the problem and the expected output you are looking for, rather than asking vague questions, you can receive more accurate answers.
#
# 2. Provide context: <br>
# When asking questions, it's helpful to provide not only the problematic portion of the code but also the surrounding context. This allows the AI to better understand the overall issue.
#
# 3. Include error messages: <br>
# If error messages are displayed, make sure to include them as well. Error messages can help in identifying the problem.

# %% [markdown]
# ##Mount tutorial files to your COLAB drive
# Here is how to get files into your colab so you can refer to them in your code. To do this we will be using the *GitHub repository* I have set up for the class. GitHub is a major professional code "repo" and team (or individual) development environment.
#
#
# 1.   Run this code: ` !git clone https://github.com/atkinsonde/230_2025.git` in one of your cells. I've already put it in. Click in the cell and type the Control key (CTRL)+Enter at the same time to run the code in any one cell (OR just click on the black circle with the triangle).
#
# 2.   Once you have run the git code look on the menu on the left. Look for the key symbol and click the folder underneath to open up a window to the left of your code window (if the window is already open, clicking the folder will collapse it and widen your coding area).
#
# 3.   With the window open, you will see at the top the word "Files" and a series of four icons below it. Below, you will see a folder called "sample_data". Click on the refresh folder icon (the one with the little circle arrow on it, not the recycle one). Another folder will appear called "230_2025". (The little triangles on the left will rotate down when the folders are open). <br><br>
#
# 4.   If you click on "230_2025" you will see a sub-folder called "Tutorial_2". If you click on that, you will see a series of files. These are the files we will work with in this tutorial.
#
# The "refresh" folder icon looks like this: <br>
#
# ![refresh_folder.PNG](data:image/png;base64,...)

# %%
# !git clone https://github.com/atkinsonde/230_2025

# %% [markdown]
# # Start Creating Prompt
# Gemini is on the right top of this page. When you click the button, a new tab will open on the right side of this page.
#
# 1.   Imagine the whole process. What is the goal? What is the each step? Make note of the process and the outcome you are looking for.<br><br>
# 2.   Break out the each step and create a question to ask to Gemini. Make an effort to keep each step short.<br><br>
# Example: <br>
# [Goal]<br>
# &nbsp;&nbsp;&nbsp;&nbsp;For answering question A-1, you need a pandas.DataFrame table of all weather data with Date/time index to analyze the data.
# [Steps]<br>
# &nbsp;&nbsp;&nbsp;&nbsp;1. Use `glob.glob` to pull all the weather data files from your GitHub clone.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;2. Read the data with `pd.read_csv`.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;3. Add `parse_dates=['Date/Time']`, set_index('Date/Time').
# <br><br>
# 3.   Copy the path of "glob_data". Click the 3 dots, right side of the folder name.<br><br>
# 4.   Ask to Gemini.  Prompt = Use glob to pull all file names from '/content/230_2025/Tutorial_2/glob_data' and read them by pd.read_csv.<br><br>
# 5.   Click "Add code cell" and Run them

# %%
# Put the result code here

# %% [markdown]
# # Add questions
# Probably, you can get a simple result. Print the result "dfs.head()". You can not do it because it is list, not the pandas.DateFrame.<br>
#
#
# 1.   change to DataFrame
# 2.   add parse_dates=['Date/Time'], set_index('Date/Time')
#
# Carefully, read the "Reasoning" the Gemini provides why it chooses the code. You will understand what is going on. From question 1, Gemini chooses "ignore_index=True" to delete the index, but question 2 chooses "ignore_index=False" because Date/Time is important index to analyze the data.

# %%
import glob
import pandas as pd

file_paths = glob.glob('/content/230_2025/glob_data/*.csv')

dfs = []

for file_path in file_paths:
    # Add parse_dates and index_col here
    df = pd.read_csv(file_path, parse_dates=['Date/Time'], index_col='Date/Time')
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=False)
#Rename index column to 'dt'
combined_df.index.names = ['dt']
combined_df
# Out:
#             Longitude (x)  Latitude (y)          Station Name  Climate ID  \
# dt
# 2017-01-01        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2017-01-02        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2017-01-03        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2017-01-04        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2017-01-05        -123.32         48.41  VICTORIA GONZALES CS     1018611
# ...                   ...           ...                   ...         ...
# 2005-12-27        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2005-12-28        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2005-12-29        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2005-12-30        -123.32         48.41  VICTORIA GONZALES CS     1018611
# 2005-12-31        -123.32         48.41  VICTORIA GONZALES CS     1018611
#
# ...
